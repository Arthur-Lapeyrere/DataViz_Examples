# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Matplotlib-Librairy" data-toc-modified-id="Matplotlib-Librairy-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Matplotlib Librairy</a></span></li><li><span><a href="#Line-graphs-and-scatter-plots" data-toc-modified-id="Line-graphs-and-scatter-plots-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Line graphs and scatter plots</a></span></li><li><span><a href="#Customizing-plots" data-toc-modified-id="Customizing-plots-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Customizing plots</a></span></li><li><span><a href="#Multiple-plots" data-toc-modified-id="Multiple-plots-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Multiple plots</a></span></li><li><span><a href="#Working-with-dates-and-times" data-toc-modified-id="Working-with-dates-and-times-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Working with dates and times</a></span></li><li><span><a href="#Multiple-plots-in-one-figure" data-toc-modified-id="Multiple-plots-in-one-figure-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Multiple plots in one figure</a></span></li></ul></div>

# %% [markdown]
# # Matplotlib Librairy

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Line graphs and scatter plots

# %% [markdown]
# Making a line graph

# %%
x_values = [0, 1, 2, 3, 4, 5]
squares = [0, 1, 4, 9, 16, 25]
plt.plot(x_values, squares)
plt.show()

# %% [markdown]
# Making a scatter plot

# %%
x_values = list(range(1000))
squares = [x**2 for x in x_values]

plt.scatter(x_values, squares, s=10)
plt.show()

# %% [markdown]
# # Customizing plots

# %% [markdown]
# Adding titles and labels, and scaling axes

# %%
x_values = list(range(1000))
squares = [x**2 for x in x_values]
plt.scatter(x_values, squares, s=10)

plt.title("squares Numbers", fontsize=24)
plt.xlabel("Value", fontsize=18)
plt.ylabel("Square of Value", fontsize=18)
plt.tick_params(axis='both', which='major', labelsize=14)
plt.axis([0, 1100, 0, 1100000])

plt.show()

# %% [markdown]
# Using a colormap

# %%
plt.scatter(x_values, squares, c=squares, cmap=plt.cm.Blues, edgecolor='none', s=10)

# %% [markdown]
# Emphasizing points

# %%
x_values = list(range(1000))
squares = [x**2 for x in x_values]
plt.scatter(x_values, squares, c=squares, cmap=plt.cm.Blues, edgecolor='none', s=10)

plt.scatter(x_values[0], squares[0], c='green', edgecolor='none', s=100)
plt.scatter(x_values[-1], squares[-1], c='red', edgecolor='none', s=100)

plt.title("squares Numbers", fontsize=24)
# Out:
# Text(0.5, 1.0, 'squares Numbers')

# %% [markdown]
# Removing axes

# %%
x_values = list(range(1000))
squares = [x**2 for x in x_values]
plt.scatter(x_values, squares, c=squares, cmap=plt.cm.Blues, edgecolor='none', s=10)

plt.scatter(x_values[0], squares[0], c='green', edgecolor='none', s=100)
plt.scatter(x_values[-1], squares[-1], c='red', edgecolor='none', s=100)

plt.title("squares Numbers", fontsize=24)
plt.axes().get_xaxis().set_visible(False)
plt.axes().get_yaxis().set_visible(False)
# Out:
# <ipython-input-7-9704184bca4a>:9: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().get_xaxis().set_visible(False)
# <ipython-input-7-9704184bca4a>:10: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().get_yaxis().set_visible(False)

# %% [markdown]
# Setting a custom figure size

# %%
x_values = list(range(1000))
squares = [x**2 for x in x_values]
plt.scatter(x_values, squares, c=squares, cmap=plt.cm.Blues, edgecolor='none', s=10)

plt.scatter(x_values[0], squares[0], c='green', edgecolor='none', s=100)
plt.scatter(x_values[-1], squares[-1], c='red', edgecolor='none', s=100)

plt.title("squares Numbers", fontsize=24)

# new part
plt.figure(dpi=128, figsize=(10,6))

# %% [markdown]
# Saving a plot

# %%
plt.savefig('squares.png', bbox_inches='tight')

# %% [markdown]
# # Multiple plots

# %% [markdown]
# Plotting two sets of data

# %%
x_values = list(range(11))
squares = [x**2 for x in x_values]
cubes = [x**3 for x in x_values]

plt.scatter(x_values, squares, c='blue', edgecolor='none', s=20)
plt.scatter(x_values, cubes, c='red', edgecolor='none', s=20)

plt.axis([0, 11, 0, 1100])
plt.show()

# %% [markdown]
# Filling the space between data sets

# %%
x_values = list(range(11))
squares = [x**2 for x in x_values]
cubes = [x**3 for x in x_values]

plt.scatter(x_values, squares, c='blue', edgecolor='none', s=20)
plt.scatter(x_values, cubes, c='red', edgecolor='none', s=20)
#new element
plt.fill_between(x_values, cubes, squares, facecolor='blue', alpha=0.25)

plt.axis([0, 11, 0, 1100])
plt.show()

# %% [markdown]
# # Working with dates and times

# %%
from datetime import datetime as dt

# %% [markdown]
# Generating the current date

# %%
today = dt.now()
date_string = dt.strftime(today, '%m/%d/%Y')
print(date_string)
# Out:
# 02/06/2021

# %% [markdown]
# Generating a specific date

# %%
new_years = dt(2017, 1, 1)
fall_equinox = dt(year=2016, month=9, day=22)
print(fall_equinox)
# Out:
# 2016-09-22 00:00:00

# %% [markdown]
# Datetime formatting arguments

# %%
"""
# %A  Weekday name, such as Monday
# %B  Month name, such as January
# %m  Month, as a number (01 to 12)
# %d  Day of the month, as a number (01 to 31)
# %Y  Four-digit year, such as 2016
# %y  Two-digit year, such as 16
# %H  Hour, in 24-hour format (00 to 23)
# %I  Hour, in 12-hour format (01 to 12)
# %p  AM or PM
# %M  Minutes (00 to 59)
# %S  Seconds (00 to 61)
"""
# Out:
# '\n%A  Weekday name, such as Monday\n%B  Month name, such as January\n%m  Month, as a number (01 to 12)\n%d  Day of the month, as a number (01 to 31)\n%Y  Four-digit year, such as 2016\n%y  Two-digit year, such as 16\n%H  Hour, in 24-hour format (00 to 23)\n%I  Hour, in 12-hour format (01 to 12)\n%p  AM or PM\n%M  Minutes (00 to 59)\n%S  Seconds (00 to 61)\n'

# %% [markdown]
# Converting a string to a datetime object

# %%
new_years = dt.strptime('1/1/2017', '%m/%d/%Y')
print(new_years)
# Out:
# 2017-01-01 00:00:00

# %% [markdown]
# Converting a datetime object to a string

# %%
ny_string = dt.strftime(new_years, '%m/%d/%Y')
print(ny_string)
# Out:
# 01/01/2017

# %% [markdown]
# Plotting high temperatures

# %%
from matplotlib import dates as mdates

# %%
dates = [dt(2016, 6, 21), dt(2016, 6, 22), dt(2016, 6, 23), dt(2016, 6, 24)]
highs = [57, 68, 64, 59]

fig =plt.figure(dpi=128, figsize=(10,6))
plt.plot(dates, highs, c='red')
plt.title("Daily Hight Temps", fontsize=24)
plt.ylabel("Temp (F)", fontsize=16)
          
x_axis = plt.axes().get_xaxis()
x_axis.set_major_formatter(mdates.DateFormatter('%B %d %Y'))
fig.autofmt_xdate()
          
plt.show()
# Out:
# <ipython-input-19-24fc70f5c888>:9: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   x_axis = plt.axes().get_xaxis()

# %% [markdown]
# # Multiple plots in one figure

# %% [markdown]
# Sharing an x-axis

# %%
x_vals = list(range(11))
squares = [x**2 for x in x_values]
cubes = [x**3 for x in x_values]

fig, axarr = plt.subplots(2,1, sharex=True)

axarr[0].scatter(x_vals, squares)
axarr[0].set_title('Squares')

axarr[1].scatter(x_vals, cubes, c='red')
axarr[1].set_title('Cubes')

plt.show()

# %% [markdown]
# Sharing an y-axis

# %%
x_vals = list(range(11))
squares = [x**2 for x in x_values]
cubes = [x**3 for x in x_values]

fig, axarr = plt.subplots(1, 2, sharey=True)

axarr[0].scatter(x_vals, squares)
axarr[0].set_title('Squares')

axarr[1].scatter(x_vals, cubes, c='red')
axarr[1].set_title('Cubes')

plt.show()
